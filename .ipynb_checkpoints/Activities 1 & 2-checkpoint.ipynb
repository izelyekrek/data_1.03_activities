# %%
import pandas as pd

# %%
df1 = pd.read_excel('file3.xlsx')

# %%
df2 = pd.read_excel('file4.xlsx')

# %%
df1.columns
# Out:
# Index(['CONTROLN', 'STATE', 'GENDER', 'HV1', 'IC1', 'IC4', 'HVP1', 'IC5',
#        'POBC1', 'POBC2', 'IC2', 'IC3', 'AVGGIFT', 'TCODE', 'DOB', 'DOMAIN',
#        'TARGET_D'],
#       dtype='object')

# %%
df2.columns
# Out:
# Index(['CONTROLN', 'STATE', 'GENDER', 'HV1', 'IC1', 'IC4', 'HVP1', 'IC5',
#        'POBC1', 'POBC2', 'IC2', 'IC3', 'AVGGIFT', 'TCODE', 'DOB', 'DOMAIN',
#        'TARGET_D'],
#       dtype='object')

# %%
data = pd.concat([df1, df2], axis=0)

# %%
data
# Out:
#       CONTROLN      STATE GENDER   HV1  IC1  IC4  HVP1    IC5  POBC1  POBC2  \
# 0       119966         TX      F   321  225  281     0   9372      3     68
# 1       152470         CA      F  5725  610  807    97  53158     13     22
# 2        48527         AL   Male   931  407  496     0  17743      0     65
# 3       171528         CA      F  1895  317  471    46  17431     10     62
# 4        50122  Tennessee      F   715  318  370     2  12416      0     75
# ...        ...        ...    ...   ...  ...  ...   ...    ...    ...    ...
# 1001     41537         FL      F   742  396  470     0  15356      7     37
# 1002      4881         FL      M   599  100  423     4  11670     10     27
# 1003     66358         ND      M   593  258  299     0  10186      1     70
# 1004      2231         WI   male   564  217  397     0  12315      0     96
# 1005     68534         MI      M   651  431  505     0  14845      7     77
#
#       IC2  IC3    AVGGIFT  TCODE   DOB DOMAIN  TARGET_D
# ...

# %%
data.columns = data.columns.str.lower()
data
# Out:
#       controln      state gender   hv1  ic1  ic4  hvp1    ic5  pobc1  pobc2  \
# 0       119966         TX      F   321  225  281     0   9372      3     68
# 1       152470         CA      F  5725  610  807    97  53158     13     22
# 2        48527         AL   Male   931  407  496     0  17743      0     65
# 3       171528         CA      F  1895  317  471    46  17431     10     62
# 4        50122  Tennessee      F   715  318  370     2  12416      0     75
# ...        ...        ...    ...   ...  ...  ...   ...    ...    ...    ...
# 1001     41537         FL      F   742  396  470     0  15356      7     37
# 1002      4881         FL      M   599  100  423     4  11670     10     27
# 1003     66358         ND      M   593  258  299     0  10186      1     70
# 1004      2231         WI   male   564  217  397     0  12315      0     96
# 1005     68534         MI      M   651  431  505     0  14845      7     77
#
#       ic2  ic3    avggift  tcode   dob domain  target_d
# ...

# %%
data = data.drop(['domain'], axis=1)
data
# Out:
#       controln      state gender   hv1  ic1  ic4  hvp1    ic5  pobc1  pobc2  \
# 0       119966         TX      F   321  225  281     0   9372      3     68
# 1       152470         CA      F  5725  610  807    97  53158     13     22
# 2        48527         AL   Male   931  407  496     0  17743      0     65
# 3       171528         CA      F  1895  317  471    46  17431     10     62
# 4        50122  Tennessee      F   715  318  370     2  12416      0     75
# ...        ...        ...    ...   ...  ...  ...   ...    ...    ...    ...
# 1001     41537         FL      F   742  396  470     0  15356      7     37
# 1002      4881         FL      M   599  100  423     4  11670     10     27
# 1003     66358         ND      M   593  258  299     0  10186      1     70
# 1004      2231         WI   male   564  217  397     0  12315      0     96
# 1005     68534         MI      M   651  431  505     0  14845      7     77
#
#       ic2  ic3    avggift  tcode   dob  target_d
# ...

# %%
data = data.drop(['dob'], axis=1)

# %%
data[(data['gender']=='M') & (data['state']=='FL')]
# Out:
#       controln state gender  hv1  ic1  ic4  hvp1    ic5  pobc1  pobc2  ic2  \
# 30       35581    FL      M  906  296  473     3  16729      4     37  377
# 31       46358    FL      M  715  362  408     0  12806      6     28  371
# 38       41545    FL      M  658  373  436     0  14942     11     23  392
# 55       11284    FL      M  934  324  478     9  17408      4     11  391
# 59       25678    FL      M  721  302  365     2  12474      3     51  339
# ...        ...   ...    ...  ...  ...  ...   ...    ...    ...    ...  ...
# 962      36776    FL      M  653  319  379     0  12869     11     35  360
# 973       4881    FL      M  599  100  423     4  11670     10     27  406
# 992       6403    FL      M  677  311  313     0  12509      2     23  272
# 997       6443    FL      M  595  252  274     0  11132      8     11  263
# 1002      4881    FL      M  599  100  423     4  11670     10     27  406
#
#       ic3    avggift  tcode  target_d
# ...

# %%
data[(data['gender']=='F') & (data['ic1']<=100)]
# Out:
#      controln      state gender  hv1  ic1  ic4  hvp1    ic5  pobc1  pobc2  \
# 83     110425         LA      F  305   95  182     1   6104      0     83
# 114    160103         CA      F    0    0    0     0      0      0      0
# 128       441         IL      F  550   91  254     6  10050      0     49
# 150    126949         TX      F    0    0    0     0      0      0      0
# 280    141809         CA      F  788   71  155     0   6409     28     33
# 528    175602         OR      F  217   97  149     0   4914      1     40
# 575     53853  Tennessee      F  186   77  130     0   4365      1     78
# 735     58086         KY      F  240   99  191     0   6133      0     92
# 737     73625         MI      F    0    0    0     0      0      0      0
# 930     58079         KY      F  253   89  167     0   5372      0     83
# 344     22984         SC      F    0    0    0     0      0      0      0
# 422    131263         CO      F  475   82  125     9   7813      5     46
# ...
